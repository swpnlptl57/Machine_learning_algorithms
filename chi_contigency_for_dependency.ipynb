# %%
import numpy as np
from scipy import stats
data  = [[1,13,44,55],[1,13,44,55]]
chi_result= stats.chi2_contingency(data)
p = chi_result[1]
if (p>0.05):
    print("independent")
else:
    print("dependent")
# Out:
# independent

# %%
from matplotlib.pyplot import plot 

plot(data[0],data[1])
