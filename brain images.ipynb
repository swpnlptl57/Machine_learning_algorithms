# %%
# import all modules and packages

import numpy as np
import nibabel as nib
import itkwidgets 
import itk
from ipywidgets import interact , interactive, IntSlider , ToggleButtons
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
# load data (brain images 3D)
# https://decathlon-10.grand-challenge.org

#image_path ="C:/Users/Admin/Downloads/group_images.zip"
#image_object = nib.load(image_path)

# %%
from IPython.display import display
from PIL import Image


path="F:\Downloads\mri_result.PNG"
image = display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=376x337 at 0x1E6C6EC8EB0>

# %%
#extract data as numpy array
# get the image shape and print it out
# Visualize the data 

#select random layer number 
#maxval = 154 i= np.random.rand_int(0, max_val) signicance to view 155 slices of brain

# define channel to look at 
#channel = 0

# height , width , depth, channels = image.data.shape
# print ('dimensions:\nheight={height}\nwidth{width}\ndepth{depth}\nchannels={channels}.')

#another way of exploring data is by using ipython widgets
#def explore_3d_image(layer):
     #plt.figure(figsize=(10,15))
     #channel = 3
    #plt.imshow(image_data[:,:, channel ],cmap='gray')
    #plt.title()
    #plt.axis('off')
    #return layer
# run the ipywidgets interact() function to explore data
#interact(explore_3d_image, layer=(0, image_data[2]-1))
